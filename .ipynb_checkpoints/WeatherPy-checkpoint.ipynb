# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
import gmaps

# Import API key
from api_keys import api_key
from api_keys import gkey

#Access maps with gkey
gmaps.configure(api_key=gkey)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=3000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=3000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
lat_lngs = zip(lats, lngs)
list_lats_lngs = list(lat_lngs)
#print(list_lats_lngs)

# %%
#Seeing how spread out the coordinates are to ensure full coverage of the globe
#figure_layout = {
#    'width': '400px',
#    'height': '300px',
#    'border': '1px solid black',
#    'padding': '1px',
#    'margin': '0 auto 0 auto'}

#fig = gmaps.figure(layout=figure_layout)
#markers = gmaps.marker_layer(list_lats_lngs)
#fig.add_layer(markers)
#fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

city_sets = []
weather_list = []

for x in range(1,15):
    city_set = random.sample(cities, 50)
    city_sets.append(city_set)

print("Beginning Data Retrieval")
print("------------------------")    

weather_list = []
    
for city in cities:
        if len(weather_list) == 1000:
            print("End of Data Retrieval")
            break
        try:
            print(f"Processing Record {cities.index(city) + 1} | {city}")

            city_url = url + "appid=" + api_key + "&q=" + city
            response = requests.get(city_url)
            city_weather = response.json()    

            weather_list.append({
                "City": city_weather['name'],
                "Country": city_weather['sys']['country'],
                "Temperature": (city_weather['main']['temp'] - 273.15),
                "Humidity": city_weather['main']['humidity'],
                "Cloudiness": city_weather['clouds']['all'],
                "Max Temp": (city_weather['main']['temp_max'] - 273.15),
                "Wind Speed": city_weather['wind']['speed'],
                "Latitude": city_weather['coord']['lat'],
                "Longitude": city_weather['coord']['lon']
            })
        except KeyError:
            print("City not found.  Skipping...")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 | rikitea
# Processing Record 2 | camacupa
# Processing Record 3 | bredasdorp
# Processing Record 4 | yellowknife
# Processing Record 5 | saskylakh
# Processing Record 6 | owo
# Processing Record 7 | taolanaro
# City not found.  Skipping...
# Processing Record 8 | east london
# Processing Record 9 | fernandopolis
# Processing Record 10 | alamosa
# Processing Record 11 | dharmanagar
# Processing Record 12 | balkanabat
# Processing Record 13 | tieli
# Processing Record 14 | pevek
# Processing Record 15 | bambous virieux
# Processing Record 16 | lerwick
# Processing Record 17 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 18 | kahului
# Processing Record 19 | cape town
# Processing Record 20 | trinidad
# Processing Record 21 | ushuaia
# Processing Record 22 | inuvik
# Processing Record 23 | saqqez
# Processing Record 24 | labuhan
# Processing Record 25 | bandarbeyla
# Processing Record 26 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 27 | mayo
# Processing Record 28 | dashitou
# Processing Record 29 | saint-philippe
# Processing Record 30 | amderma
# City not found.  Skipping...
# Processing Record 31 | souillac
# Processing Record 32 | shimoda
# Processing Record 33 | port hardy
# Processing Record 34 | dalianwan
# Processing Record 35 | mahebourg
# Processing Record 36 | umzimvubu
# City not found.  Skipping...
# Processing Record 37 | rogovatoye
# Processing Record 38 | fairbanks
# Processing Record 39 | hermanus
# Processing Record 40 | mataura
# Processing Record 41 | thinadhoo
# Processing Record 42 | uyuni
# Processing Record 43 | hervey bay
# Processing Record 44 | hobart
# Processing Record 45 | isangel
# Processing Record 46 | port macquarie
# Processing Record 47 | tazovskiy
# Processing Record 48 | esperance
# Processing Record 49 | padang
# Processing Record 50 | iskateley
# Processing Record 51 | leninskoye
# Processing Record 52 | busselton
# Processing Record 53 | tessalit
# Processing Record 54 | punta arenas
# Processing Record 55 | attawapiskat
# City not found.  Skipping...
# Processing Record 56 | mongo
# Processing Record 57 | lagoa
# Processing Record 58 | mys shmidta
# City not found.  Skipping...
# Processing Record 59 | lavrentiya
# Processing Record 60 | hasaki
# Processing Record 61 | avarua
# Processing Record 62 | qaanaaq
# Processing Record 63 | vila velha
# Processing Record 64 | port elizabeth
# Processing Record 65 | butaritari
# Processing Record 66 | faanui
# Processing Record 67 | preobrazheniye
# Processing Record 68 | cabo san lucas
# Processing Record 69 | barawe
# City not found.  Skipping...
# Processing Record 70 | bethel
# Processing Record 71 | upernavik
# Processing Record 72 | sur
# Processing Record 73 | kawalu
# Processing Record 74 | mar del plata
# Processing Record 75 | puerto ayora
# Processing Record 76 | flinders
# Processing Record 77 | anadyr
# Processing Record 78 | chapais
# Processing Record 79 | atuona
# Processing Record 80 | grand centre
# City not found.  Skipping...
# Processing Record 81 | glendive
# Processing Record 82 | kamien pomorski
# Processing Record 83 | bilma
# Processing Record 84 | hilo
# Processing Record 85 | guerrero negro
# Processing Record 86 | tasiilaq
# Processing Record 87 | smithers
# Processing Record 88 | olinda
# Processing Record 89 | bluff
# Processing Record 90 | dembi dolo
# Processing Record 91 | kapaa
# Processing Record 92 | rusape
# Processing Record 93 | ponta do sol
# Processing Record 94 | albany
# Processing Record 95 | moose factory
# Processing Record 96 | nantucket
# Processing Record 97 | new norfolk
# Processing Record 98 | batagay-alyta
# Processing Record 99 | saint-joseph
# Processing Record 100 | plettenberg bay
# Processing Record 101 | hamilton
# Processing Record 102 | muhororo
# Processing Record 103 | victoria
# Processing Record 104 | ust-kulom
# Processing Record 105 | dzhusaly
# City not found.  Skipping...
# Processing Record 106 | torbay
# Processing Record 107 | kulhudhuffushi
# Processing Record 108 | diamantino
# Processing Record 109 | dubai
# Processing Record 110 | yar-sale
# Processing Record 111 | nanortalik
# Processing Record 112 | bertoua
# Processing Record 113 | fortuna
# Processing Record 114 | omsukchan
# Processing Record 115 | marawi
# Processing Record 116 | norman wells
# Processing Record 117 | jamestown
# Processing Record 118 | vaini
# Processing Record 119 | cidreira
# Processing Record 120 | bowen
# Processing Record 121 | kodiak
# Processing Record 122 | grand-santi
# Processing Record 123 | san jose
# Processing Record 124 | abbotsford
# Processing Record 125 | kailua
# Processing Record 126 | botwood
# Processing Record 127 | necochea
# Processing Record 128 | pundaguitan
# Processing Record 129 | vinnytsya
# Processing Record 130 | hithadhoo
# Processing Record 131 | ancud
# Processing Record 132 | khatanga
# Processing Record 133 | georgetown
# Processing Record 134 | severo-kurilsk
# Processing Record 135 | port hedland
# Processing Record 136 | bandar-e anzali
# Processing Record 137 | goundam
# Processing Record 138 | beian
# Processing Record 139 | balad
# Processing Record 140 | tuktoyaktuk
# Processing Record 141 | aasiaat
# Processing Record 142 | tierralta
# Processing Record 143 | lebu
# Processing Record 144 | baixa grande
# Processing Record 145 | longyearbyen
# Processing Record 146 | airai
# Processing Record 147 | barrow
# Processing Record 148 | faya
# Processing Record 149 | rungata
# City not found.  Skipping...
# Processing Record 150 | pochutla
# Processing Record 151 | castro
# Processing Record 152 | zaterechnyy
# Processing Record 153 | namibe
# Processing Record 154 | vostok
# Processing Record 155 | carnarvon
# Processing Record 156 | diu
# Processing Record 157 | thompson
# Processing Record 158 | husavik
# Processing Record 159 | namatanai
# Processing Record 160 | vila franca do campo
# Processing Record 161 | chernyshevskiy
# Processing Record 162 | vaitupu
# City not found.  Skipping...
# Processing Record 163 | alice springs
# Processing Record 164 | meulaboh
# Processing Record 165 | samana
# Processing Record 166 | komsomolskiy
# Processing Record 167 | porto torres
# Processing Record 168 | tianpeng
# Processing Record 169 | saleaula
# City not found.  Skipping...
# Processing Record 170 | celestun
# Processing Record 171 | katsuura
# Processing Record 172 | chuy
# Processing Record 173 | alugan
# Processing Record 174 | thunder bay
# Processing Record 175 | ust-maya
# Processing Record 176 | sao filipe
# Processing Record 177 | hereford
# Processing Record 178 | kaitangata
# Processing Record 179 | amudat
# Processing Record 180 | kenai
# Processing Record 181 | oistins
# Processing Record 182 | muros
# Processing Record 183 | saldanha
# Processing Record 184 | oranjemund
# Processing Record 185 | barentsburg
# City not found.  Skipping...
# Processing Record 186 | tsihombe
# City not found.  Skipping...
# Processing Record 187 | kununurra
# Processing Record 188 | sheridan
# Processing Record 189 | orange
# Processing Record 190 | san patricio
# Processing Record 191 | bolobo
# Processing Record 192 | paucartambo
# City not found.  Skipping...
# Processing Record 193 | willowmore
# Processing Record 194 | tiksi
# Processing Record 195 | morros
# Processing Record 196 | antofagasta
# Processing Record 197 | hojai
# Processing Record 198 | egvekinot
# Processing Record 199 | dovbysh
# Processing Record 200 | verkh-usugli
# Processing Record 201 | artesia
# Processing Record 202 | dingle
# Processing Record 203 | hami
# Processing Record 204 | chardara
# City not found.  Skipping...
# Processing Record 205 | nome
# Processing Record 206 | gobabis
# Processing Record 207 | ueckermunde
# Processing Record 208 | colac
# Processing Record 209 | berlevag
# Processing Record 210 | henties bay
# Processing Record 211 | lethem
# Processing Record 212 | kutum
# Processing Record 213 | vao
# Processing Record 214 | benghazi
# Processing Record 215 | porto santo
# City not found.  Skipping...
# Processing Record 216 | korhogo
# Processing Record 217 | saint-pierre
# Processing Record 218 | provideniya
# Processing Record 219 | pemba
# Processing Record 220 | leningradskiy
# Processing Record 221 | jabinyanah
# Processing Record 222 | lagos
# Processing Record 223 | suao
# City not found.  Skipping...
# Processing Record 224 | nikolskoye
# Processing Record 225 | barcelos
# Processing Record 226 | itapaci
# Processing Record 227 | aleksandrov gay
# Processing Record 228 | geraldton
# Processing Record 229 | coquimbo
# Processing Record 230 | suslovo
# Processing Record 231 | saint-ambroise
# Processing Record 232 | betanzos
# Processing Record 233 | timra
# Processing Record 234 | itarema
# Processing Record 235 | margate
# Processing Record 236 | belyy yar
# Processing Record 237 | berdigestyakh
# Processing Record 238 | chokurdakh
# Processing Record 239 | hovd
# Processing Record 240 | biloela
# Processing Record 241 | ormara
# Processing Record 242 | cradock
# Processing Record 243 | ahipara
# Processing Record 244 | mahon
# Processing Record 245 | farah
# Processing Record 246 | oktyabrskiy
# Processing Record 247 | maningrida
# Processing Record 248 | balkhash
# Processing Record 249 | cherskiy
# Processing Record 250 | hobyo
# Processing Record 251 | kaeo
# Processing Record 252 | mackenzie
# Processing Record 253 | papetoai
# Processing Record 254 | keuruu
# Processing Record 255 | dikson
# Processing Record 256 | udachnyy
# Processing Record 257 | ryotsu
# Processing Record 258 | foz
# Processing Record 259 | terekli-mekteb
# Processing Record 260 | dwarka
# Processing Record 261 | jiangyou
# Processing Record 262 | massakory
# Processing Record 263 | narsaq
# Processing Record 264 | alta floresta
# Processing Record 265 | belushya guba
# City not found.  Skipping...
# Processing Record 266 | flin flon
# Processing Record 267 | zhovti vody
# Processing Record 268 | toliary
# City not found.  Skipping...
# Processing Record 269 | saint george
# Processing Record 270 | guhagar
# Processing Record 271 | arraial do cabo
# Processing Record 272 | kavieng
# Processing Record 273 | vestmanna
# Processing Record 274 | bichena
# Processing Record 275 | qeshm
# Processing Record 276 | cabreuva
# Processing Record 277 | constitucion
# Processing Record 278 | saint-leu
# Processing Record 279 | aswan
# Processing Record 280 | nuuk
# Processing Record 281 | greensburg
# Processing Record 282 | shache
# Processing Record 283 | argayash
# Processing Record 284 | matay
# Processing Record 285 | north myrtle beach
# Processing Record 286 | vardo
# Processing Record 287 | barauna
# Processing Record 288 | puerto penasco
# Processing Record 289 | presidente medici
# Processing Record 290 | yumen
# Processing Record 291 | christchurch
# Processing Record 292 | north bend
# Processing Record 293 | sedelnikovo
# City not found.  Skipping...
# Processing Record 294 | bluefields
# Processing Record 295 | iquique
# Processing Record 296 | palmer
# Processing Record 297 | pisco
# Processing Record 298 | palabuhanratu
# City not found.  Skipping...
# Processing Record 299 | port blair
# Processing Record 300 | anloga
# Processing Record 301 | nizhneyansk
# City not found.  Skipping...
# Processing Record 302 | saint-georges
# Processing Record 303 | pitimbu
# Processing Record 304 | ordynskoye
# Processing Record 305 | viedma
# Processing Record 306 | segovia
# Processing Record 307 | port alfred
# Processing Record 308 | lipin bor
# Processing Record 309 | lolua
# City not found.  Skipping...
# Processing Record 310 | san carlos de bariloche
# Processing Record 311 | evensk
# Processing Record 312 | nelson bay
# Processing Record 313 | kruisfontein
# Processing Record 314 | brae
# Processing Record 315 | rawson
# Processing Record 316 | cayenne
# Processing Record 317 | asau
# City not found.  Skipping...
# Processing Record 318 | havre-saint-pierre
# Processing Record 319 | valleyview
# Processing Record 320 | batagay
# Processing Record 321 | yunjinghong
# City not found.  Skipping...
# Processing Record 322 | hakkari
# Processing Record 323 | kovdor
# Processing Record 324 | shuiji
# Processing Record 325 | batsfjord
# Processing Record 326 | velagici
# Processing Record 327 | cabedelo
# Processing Record 328 | voronovytsya
# Processing Record 329 | grindavik
# Processing Record 330 | staryy nadym
# Processing Record 331 | adrasmon
# Processing Record 332 | prince rupert
# Processing Record 333 | sibolga
# Processing Record 334 | rawah
# City not found.  Skipping...
# Processing Record 335 | burnie
# Processing Record 336 | yambio
# City not found.  Skipping...
# Processing Record 337 | manta
# Processing Record 338 | temir
# Processing Record 339 | bambanglipuro
# Processing Record 340 | bereda
# Processing Record 341 | bengkulu
# City not found.  Skipping...
# Processing Record 342 | nemuro
# Processing Record 343 | samusu
# City not found.  Skipping...
# Processing Record 344 | rawannawi
# City not found.  Skipping...
# Processing Record 345 | vorsma
# Processing Record 346 | la ronge
# Processing Record 347 | hualmay
# Processing Record 348 | parry sound
# Processing Record 349 | balimo
# City not found.  Skipping...
# Processing Record 350 | bogande
# Processing Record 351 | gijon
# Processing Record 352 | port hawkesbury
# Processing Record 353 | concordia
# Processing Record 354 | kieta
# Processing Record 355 | kamaishi
# Processing Record 356 | tura
# Processing Record 357 | korla
# City not found.  Skipping...
# Processing Record 358 | eden
# Processing Record 359 | agirish
# Processing Record 360 | port lincoln
# Processing Record 361 | ribeira grande
# Processing Record 362 | los llanos de aridane
# Processing Record 363 | saint-malo
# Processing Record 364 | xuanzhou
# Processing Record 365 | karaman
# Processing Record 366 | juneau
# Processing Record 367 | ikare
# Processing Record 368 | kidal
# Processing Record 369 | quatre cocos
# Processing Record 370 | cairo
# Processing Record 371 | codrington
# Processing Record 372 | buala
# Processing Record 373 | ler
# Processing Record 374 | broken hill
# Processing Record 375 | ko samui
# Processing Record 376 | slave lake
# Processing Record 377 | nakapiripirit
# Processing Record 378 | nangomba
# Processing Record 379 | luderitz
# Processing Record 380 | liverpool
# Processing Record 381 | krasnoselkup
# City not found.  Skipping...
# Processing Record 382 | juegang
# Processing Record 383 | kualakapuas
# Processing Record 384 | srednekolymsk
# Processing Record 385 | zhangye
# Processing Record 386 | phangnga
# Processing Record 387 | tooele
# Processing Record 388 | poya
# Processing Record 389 | matola
# Processing Record 390 | tlaxiaco
# City not found.  Skipping...
# Processing Record 391 | corner brook
# Processing Record 392 | sitka
# Processing Record 393 | vanimo
# Processing Record 394 | fort-shevchenko
# Processing Record 395 | bur gabo
# City not found.  Skipping...
# Processing Record 396 | kyshtovka
# Processing Record 397 | zvishavane
# Processing Record 398 | ilulissat
# Processing Record 399 | xingcheng
# Processing Record 400 | bougouni
# Processing Record 401 | chalmette
# Processing Record 402 | milkovo
# Processing Record 403 | torres
# Processing Record 404 | puerto escondido
# Processing Record 405 | stoyba
# City not found.  Skipping...
# Processing Record 406 | cap malheureux
# Processing Record 407 | alyangula
# Processing Record 408 | bitkine
# Processing Record 409 | poum
# Processing Record 410 | ankpa
# Processing Record 411 | hutchinson
# Processing Record 412 | qaqortoq
# Processing Record 413 | samarai
# Processing Record 414 | bosaso
# Processing Record 415 | veshkayma
# Processing Record 416 | sakakah
# City not found.  Skipping...
# Processing Record 417 | conde
# Processing Record 418 | san cristobal
# Processing Record 419 | morgan city
# Processing Record 420 | ornskoldsvik
# Processing Record 421 | auki
# Processing Record 422 | albanel
# Processing Record 423 | sol-iletsk
# Processing Record 424 | lompoc
# Processing Record 425 | hjelset
# Processing Record 426 | muisne
# Processing Record 427 | vinh
# Processing Record 428 | iqaluit
# Processing Record 429 | izumo
# Processing Record 430 | terracina
# Processing Record 431 | imbituba
# Processing Record 432 | san roque
# Processing Record 433 | mehamn
# Processing Record 434 | lasa
# Processing Record 435 | baturaja
# Processing Record 436 | ieper
# Processing Record 437 | kamenka
# Processing Record 438 | nagua
# Processing Record 439 | neuquen
# Processing Record 440 | fort wellington
# Processing Record 441 | santa ana
# Processing Record 442 | sandwick
# Processing Record 443 | phetchabun
# Processing Record 444 | grand river south east
# City not found.  Skipping...
# Processing Record 445 | presidencia roque saenz pena
# Processing Record 446 | rio grande
# Processing Record 447 | haines junction
# Processing Record 448 | kirakira
# Processing Record 449 | northampton
# Processing Record 450 | bathsheba
# Processing Record 451 | lakefield
# Processing Record 452 | tarsus
# Processing Record 453 | guarapari
# Processing Record 454 | bjornevatn
# Processing Record 455 | jasper
# Processing Record 456 | clyde river
# Processing Record 457 | boddam
# Processing Record 458 | binga
# Processing Record 459 | berasia
# Processing Record 460 | zhireken
# Processing Record 461 | gaozhou
# Processing Record 462 | aksu
# Processing Record 463 | teknaf
# Processing Record 464 | kavaratti
# Processing Record 465 | road town
# Processing Record 466 | sortavala
# Processing Record 467 | talnakh
# Processing Record 468 | alofi
# Processing Record 469 | tiruvottiyur
# City not found.  Skipping...
# Processing Record 470 | kemijarvi
# City not found.  Skipping...
# Processing Record 471 | ariquemes
# Processing Record 472 | ewa beach
# Processing Record 473 | koslan
# Processing Record 474 | sidi ali
# Processing Record 475 | coihaique
# Processing Record 476 | darhan
# Processing Record 477 | sao joao da barra
# Processing Record 478 | talkha
# Processing Record 479 | morant bay
# Processing Record 480 | moba
# Processing Record 481 | caravelas
# Processing Record 482 | palana
# Processing Record 483 | salinas
# Processing Record 484 | harper
# Processing Record 485 | bolungarvik
# City not found.  Skipping...
# Processing Record 486 | palmeirais
# Processing Record 487 | tocache
# Processing Record 488 | ndola
# Processing Record 489 | ixtapa
# Processing Record 490 | voh
# Processing Record 491 | praia da vitoria
# Processing Record 492 | boulder
# Processing Record 493 | chachapoyas
# Processing Record 494 | goderich
# Processing Record 495 | luwuk
# Processing Record 496 | la macarena
# Processing Record 497 | kinablangan
# Processing Record 498 | tarabha
# Processing Record 499 | ovalle
# Processing Record 500 | koutiala
# Processing Record 501 | vila do maio
# Processing Record 502 | tezu
# Processing Record 503 | pinas
# Processing Record 504 | changji
# Processing Record 505 | waterfoot
# Processing Record 506 | mount isa
# Processing Record 507 | taoudenni
# Processing Record 508 | grand gaube
# Processing Record 509 | inndyr
# Processing Record 510 | carballo
# Processing Record 511 | arlit
# Processing Record 512 | arona
# Processing Record 513 | maarianhamina
# City not found.  Skipping...
# Processing Record 514 | san quintin
# Processing Record 515 | severnyy
# City not found.  Skipping...
# Processing Record 516 | snezhnogorsk
# Processing Record 517 | cockburn town
# Processing Record 518 | omboue
# Processing Record 519 | saint-francois
# Processing Record 520 | istok
# Processing Record 521 | houma
# Processing Record 522 | peniche
# Processing Record 523 | tumannyy
# City not found.  Skipping...
# Processing Record 524 | tigil
# Processing Record 525 | aykhal
# Processing Record 526 | aste
# Processing Record 527 | san-pedro
# Processing Record 528 | baykit
# Processing Record 529 | xihe
# Processing Record 530 | zanjan
# Processing Record 531 | marsa matruh
# Processing Record 532 | erdaojiang
# Processing Record 533 | tres picos
# Processing Record 534 | camacha
# Processing Record 535 | elverum
# Processing Record 536 | douglas
# Processing Record 537 | salalah
# Processing Record 538 | hearst
# Processing Record 539 | ust-omchug
# Processing Record 540 | lorengau
# Processing Record 541 | adre
# Processing Record 542 | benguela
# Processing Record 543 | dali
# Processing Record 544 | sao jose da coroa grande
# Processing Record 545 | bajo baudo
# City not found.  Skipping...
# Processing Record 546 | camopi
# Processing Record 547 | ziro
# Processing Record 548 | san luis
# Processing Record 549 | horqueta
# Processing Record 550 | urubicha
# Processing Record 551 | menongue
# Processing Record 552 | liwale
# Processing Record 553 | beachwood
# Processing Record 554 | tala
# Processing Record 555 | sambava
# Processing Record 556 | berezovka
# Processing Record 557 | san jeronimo
# Processing Record 558 | boffa
# Processing Record 559 | george
# Processing Record 560 | paita
# Processing Record 561 | dera ghazi khan
# Processing Record 562 | asfi
# City not found.  Skipping...
# Processing Record 563 | sao felix do xingu
# Processing Record 564 | sarakhs
# Processing Record 565 | halalo
# City not found.  Skipping...
# Processing Record 566 | tecoanapa
# Processing Record 567 | las vegas
# Processing Record 568 | puerto carreno
# Processing Record 569 | atikokan
# Processing Record 570 | tromso
# Processing Record 571 | kuhdasht
# Processing Record 572 | aranda de duero
# Processing Record 573 | sao raimundo nonato
# City not found.  Skipping...
# Processing Record 574 | chimore
# Processing Record 575 | mujiayingzi
# Processing Record 576 | gravdal
# Processing Record 577 | avera
# Processing Record 578 | college
# Processing Record 579 | tara
# Processing Record 580 | portland
# Processing Record 581 | lakes entrance
# Processing Record 582 | noumea
# Processing Record 583 | likasi
# Processing Record 584 | wageningen
# Processing Record 585 | sawtell
# Processing Record 586 | mogadishu
# Processing Record 587 | poretskoye
# Processing Record 588 | broome
# Processing Record 589 | gohad
# Processing Record 590 | marcona
# City not found.  Skipping...
# Processing Record 591 | beyneu
# Processing Record 592 | leh
# Processing Record 593 | pangnirtung
# Processing Record 594 | zirandaro
# Processing Record 595 | hegang
# Processing Record 596 | atherton
# Processing Record 597 | dudinka
# Processing Record 598 | ribeirao bonito
# Processing Record 599 | kalmunai
# Processing Record 600 | nishihara
# Processing Record 601 | beipiao
# Processing Record 602 | amapa
# Processing Record 603 | mayumba
# Processing Record 604 | la rochelle
# Processing Record 605 | conil
# Processing Record 606 | pamanukan
# Processing Record 607 | honiara
# Processing Record 608 | hofn
# Processing Record 609 | chabahar
# Processing Record 610 | zhanakorgan
# Processing Record 611 | conceicao do araguaia
# Processing Record 612 | siare
# City not found.  Skipping...
# Processing Record 613 | oriximina
# Processing Record 614 | gorontalo
# Processing Record 615 | sorland
# Processing Record 616 | sydney
# Processing Record 617 | petropavlovsk-kamchatskiy
# Processing Record 618 | saint-augustin
# Processing Record 619 | strezhevoy
# Processing Record 620 | atambua
# Processing Record 621 | ojinaga
# Processing Record 622 | tabou
# Processing Record 623 | mergui
# City not found.  Skipping...
# Processing Record 624 | sindor
# Processing Record 625 | warmbad
# Processing Record 626 | utiroa
# City not found.  Skipping...
# Processing Record 627 | tamale
# Processing Record 628 | warqla
# City not found.  Skipping...
# Processing Record 629 | khorixas
# Processing Record 630 | svetlyy
# City not found.  Skipping...
# Processing Record 631 | vangaindrano
# Processing Record 632 | tranas
# Processing Record 633 | gat
# Processing Record 634 | solnechnyy
# Processing Record 635 | estelle
# Processing Record 636 | merauke
# Processing Record 637 | tuatapere
# Processing Record 638 | pilna
# Processing Record 639 | soyo
# Processing Record 640 | saryshagan
# City not found.  Skipping...
# Processing Record 641 | impfondo
# Processing Record 642 | pinotepa nacional
# City not found.  Skipping...
# Processing Record 643 | kargasok
# Processing Record 644 | bulgan
# Processing Record 645 | dicabisagan
# Processing Record 646 | inverness
# Processing Record 647 | beroroha
# Processing Record 648 | medicine hat
# Processing Record 649 | mumford
# Processing Record 650 | wanning
# Processing Record 651 | abu kamal
# Processing Record 652 | port jervis
# Processing Record 653 | seoul
# Processing Record 654 | decatur
# Processing Record 655 | jimeta
# Processing Record 656 | ratnagiri
# Processing Record 657 | shingu
# Processing Record 658 | san julian
# Processing Record 659 | mandera
# Processing Record 660 | morondava
# Processing Record 661 | vancouver
# Processing Record 662 | surt
# Processing Record 663 | illapel
# Processing Record 664 | naze
# Processing Record 665 | jaleswar
# Processing Record 666 | mana
# Processing Record 667 | khani
# Processing Record 668 | kyritz
# Processing Record 669 | saint simons
# Processing Record 670 | vozrozhdeniye
# Processing Record 671 | sabinov
# Processing Record 672 | sinjah
# City not found.  Skipping...
# Processing Record 673 | yabelo
# Processing Record 674 | sal rei
# Processing Record 675 | raudeberg
# Processing Record 676 | tidore
# City not found.  Skipping...
# Processing Record 677 | nabire
# Processing Record 678 | zhuhai
# Processing Record 679 | kadom
# Processing Record 680 | slavyanka
# Processing Record 681 | karratha
# Processing Record 682 | sierra vista
# Processing Record 683 | piacabucu
# Processing Record 684 | regina
# Processing Record 685 | jyvaskyla
# City not found.  Skipping...
# Processing Record 686 | baracoa
# Processing Record 687 | roches noires
# City not found.  Skipping...
# Processing Record 688 | ilam
# Processing Record 689 | ardistan
# City not found.  Skipping...
# Processing Record 690 | xudat
# Processing Record 691 | charters towers
# Processing Record 692 | pangani
# Processing Record 693 | mangan
# Processing Record 694 | ostrovnoy
# Processing Record 695 | znamenskoye
# Processing Record 696 | pokhara
# Processing Record 697 | touros
# Processing Record 698 | beringovskiy
# Processing Record 699 | tambovka
# Processing Record 700 | deh rawud
# City not found.  Skipping...
# Processing Record 701 | kachiry
# Processing Record 702 | cornwall
# Processing Record 703 | soria
# Processing Record 704 | meadow lake
# Processing Record 705 | ust-kamchatsk
# City not found.  Skipping...
# Processing Record 706 | comodoro rivadavia
# Processing Record 707 | uribia
# Processing Record 708 | moron
# Processing Record 709 | lesosibirsk
# Processing Record 710 | tautira
# Processing Record 711 | empalme
# Processing Record 712 | mosetse
# Processing Record 713 | morrisburg
# Processing Record 714 | senmonorom
# City not found.  Skipping...
# Processing Record 715 | gorkovskoye
# City not found.  Skipping...
# Processing Record 716 | soe
# Processing Record 717 | yaan
# Processing Record 718 | casas grandes
# Processing Record 719 | santa maria
# Processing Record 720 | santa isabel
# Processing Record 721 | grand island
# Processing Record 722 | novovasylivka
# Processing Record 723 | shangzhi
# Processing Record 724 | lake havasu city
# Processing Record 725 | atar
# Processing Record 726 | qui nhon
# City not found.  Skipping...
# Processing Record 727 | wilmington
# Processing Record 728 | xuddur
# Processing Record 729 | guarare
# Processing Record 730 | porto novo
# Processing Record 731 | bubaque
# Processing Record 732 | ossora
# Processing Record 733 | cheltenham
# Processing Record 734 | ocos
# Processing Record 735 | sadove
# Processing Record 736 | sinnamary
# Processing Record 737 | launceston
# Processing Record 738 | port keats
# Processing Record 739 | akyab
# City not found.  Skipping...
# Processing Record 740 | albina
# Processing Record 741 | mazagao
# Processing Record 742 | englewood
# Processing Record 743 | pandan niog
# Processing Record 744 | erzin
# Processing Record 745 | dhidhdhoo
# Processing Record 746 | buraydah
# Processing Record 747 | buritis
# Processing Record 748 | reftinskiy
# Processing Record 749 | huarmey
# Processing Record 750 | boke
# Processing Record 751 | skotterud
# Processing Record 752 | san rafael del sur
# Processing Record 753 | winton
# Processing Record 754 | sarkand
# Processing Record 755 | zanatepec
# City not found.  Skipping...
# Processing Record 756 | clayton
# Processing Record 757 | laguna
# Processing Record 758 | bhindar
# Processing Record 759 | shimanovsk
# Processing Record 760 | newburn
# Processing Record 761 | mapimi
# Processing Record 762 | hay river
# Processing Record 763 | pingliang
# Processing Record 764 | coahuayana
# Processing Record 765 | hukuntsi
# Processing Record 766 | taltal
# Processing Record 767 | pareora
# Processing Record 768 | rocha
# Processing Record 769 | yahualica
# Processing Record 770 | lahat
# Processing Record 771 | canutama
# Processing Record 772 | graaff-reinet
# Processing Record 773 | myitkyina
# Processing Record 774 | price
# Processing Record 775 | dunedin
# Processing Record 776 | passo de camaragibe
# Processing Record 777 | san onofre
# Processing Record 778 | zongozotla
# Processing Record 779 | lephepe
# City not found.  Skipping...
# Processing Record 780 | olafsvik
# City not found.  Skipping...
# Processing Record 781 | vilyuysk
# Processing Record 782 | pavagada
# Processing Record 783 | yining
# Processing Record 784 | fare
# Processing Record 785 | antsohihy
# Processing Record 786 | bocaranga
# City not found.  Skipping...
# Processing Record 787 | kloulklubed
# Processing Record 788 | norsup
# Processing Record 789 | colares
# Processing Record 790 | bahar
# Processing Record 791 | ayagoz
# Processing Record 792 | fayaoue
# Processing Record 793 | ji-parana
# City not found.  Skipping...
# Processing Record 794 | micheweni
# Processing Record 795 | gambela
# Processing Record 796 | nguiu
# City not found.  Skipping...
# Processing Record 797 | vila
# Processing Record 798 | kayerkan
# Processing Record 799 | praia
# Processing Record 800 | talcahuano
# Processing Record 801 | chunskiy
# Processing Record 802 | sogdiondon
# City not found.  Skipping...
# Processing Record 803 | fort nelson
# Processing Record 804 | tiznit
# Processing Record 805 | devonport
# Processing Record 806 | manavalakurichi
# Processing Record 807 | san carlos
# Processing Record 808 | doha
# Processing Record 809 | poronaysk
# Processing Record 810 | magadan
# Processing Record 811 | tigzirt
# Processing Record 812 | hihifo
# City not found.  Skipping...
# Processing Record 813 | honningsvag
# Processing Record 814 | koumac
# Processing Record 815 | richards bay
# Processing Record 816 | natal
# Processing Record 817 | jiaocheng
# Processing Record 818 | labuan
# Processing Record 819 | challans
# Processing Record 820 | mesyagutovo
# Processing Record 821 | townsville
# Processing Record 822 | west lorne
# Processing Record 823 | krasnaya gorka
# Processing Record 824 | camargo
# Processing Record 825 | berbera
# City not found.  Skipping...
# Processing Record 826 | san rafael
# Processing Record 827 | loma bonita
# Processing Record 828 | gladstone
# Processing Record 829 | boca do acre
# Processing Record 830 | gatesville
# Processing Record 831 | santa rosa
# Processing Record 832 | klaksvik
# Processing Record 833 | kajaani
# Processing Record 834 | akureyri
# Processing Record 835 | skalistyy
# City not found.  Skipping...
# Processing Record 836 | phalodi
# Processing Record 837 | osinki
# Processing Record 838 | karasjok
# Processing Record 839 | marang
# City not found.  Skipping...
# Processing Record 840 | sekoma
# Processing Record 841 | pocatello
# Processing Record 842 | tartagal
# Processing Record 843 | cagdianao
# Processing Record 844 | kirkwall
# Processing Record 845 | saint-lo
# Processing Record 846 | bantry
# City not found.  Skipping...
# Processing Record 847 | paamiut
# Processing Record 848 | roald
# Processing Record 849 | ostersund
# Processing Record 850 | eganville
# Processing Record 851 | zhezkazgan
# Processing Record 852 | tanete
# Processing Record 853 | ambanja
# Processing Record 854 | ulaangom
# Processing Record 855 | buckeye
# Processing Record 856 | torrijos
# Processing Record 857 | scarborough
# Processing Record 858 | santa isabel do rio negro
# Processing Record 859 | yairipok
# Processing Record 860 | matao
# Processing Record 861 | karkaralinsk
# City not found.  Skipping...
# Processing Record 862 | azimur
# City not found.  Skipping...
# Processing Record 863 | pecos
# Processing Record 864 | kelowna
# Processing Record 865 | imeni poliny osipenko
# Processing Record 866 | katsina
# Processing Record 867 | cam ranh
# Processing Record 868 | pyapon
# Processing Record 869 | helong
# Processing Record 870 | urumqi
# City not found.  Skipping...
# Processing Record 871 | werdau
# Processing Record 872 | beloha
# Processing Record 873 | aklavik
# Processing Record 874 | lazaro cardenas
# Processing Record 875 | cassilandia
# Processing Record 876 | acari
# Processing Record 877 | la asuncion
# Processing Record 878 | half moon bay
# Processing Record 879 | tchollire
# Processing Record 880 | ust-nera
# Processing Record 881 | owando
# Processing Record 882 | bafata
# Processing Record 883 | hirara
# Processing Record 884 | sulangan
# Processing Record 885 | yeniseysk
# Processing Record 886 | excelsior springs
# Processing Record 887 | verkhnevilyuysk
# Processing Record 888 | iralaya
# Processing Record 889 | carmen
# Processing Record 890 | mackay
# Processing Record 891 | haibowan
# City not found.  Skipping...
# Processing Record 892 | svetlogorsk
# Processing Record 893 | parvatipuram
# Processing Record 894 | petauke
# Processing Record 895 | sisimiut
# Processing Record 896 | general roca
# Processing Record 897 | carupano
# Processing Record 898 | igrim
# Processing Record 899 | skelleftea
# Processing Record 900 | bollnas
# Processing Record 901 | torrington
# Processing Record 902 | wenchi
# Processing Record 903 | cairns
# Processing Record 904 | general pico
# Processing Record 905 | beihai
# Processing Record 906 | chitrakonda
# Processing Record 907 | te anau
# Processing Record 908 | hambantota
# Processing Record 909 | ucluelet
# Processing Record 910 | bagdarin
# Processing Record 911 | nurota
# Processing Record 912 | sola
# Processing Record 913 | suamico
# Processing Record 914 | lichinga
# Processing Record 915 | pangai
# Processing Record 916 | torun
# Processing Record 917 | abhar
# Processing Record 918 | inirida
# Processing Record 919 | valparaiso
# Processing Record 920 | pacifica
# Processing Record 921 | oparino
# Processing Record 922 | neryungri
# Processing Record 923 | oyama
# Processing Record 924 | maracas
# Processing Record 925 | acapulco
# Processing Record 926 | merced
# Processing Record 927 | kamiiso
# Processing Record 928 | mongu
# Processing Record 929 | dickinson
# Processing Record 930 | karamay
# City not found.  Skipping...
# Processing Record 931 | mitu
# Processing Record 932 | greenville
# Processing Record 933 | mwense
# Processing Record 934 | trelew
# Processing Record 935 | maumere
# Processing Record 936 | golden
# Processing Record 937 | saint-louis
# Processing Record 938 | pontianak
# Processing Record 939 | cootamundra
# Processing Record 940 | novopokrovka
# Processing Record 941 | umm durman
# City not found.  Skipping...
# Processing Record 942 | asosa
# Processing Record 943 | pasco
# Processing Record 944 | arandelovac
# City not found.  Skipping...
# Processing Record 945 | opuwo
# Processing Record 946 | sloboda
# Processing Record 947 | bodden town
# Processing Record 948 | luanda
# Processing Record 949 | trincomalee
# Processing Record 950 | pekan
# Processing Record 951 | cobija
# Processing Record 952 | aksha
# Processing Record 953 | gubskaya
# Processing Record 954 | banff
# Processing Record 955 | yirol
# City not found.  Skipping...
# Processing Record 956 | coyah
# Processing Record 957 | khuzhir
# Processing Record 958 | altus
# Processing Record 959 | grove city
# Processing Record 960 | pachino
# Processing Record 961 | homer
# Processing Record 962 | lesnikovo
# Processing Record 963 | sorvag
# City not found.  Skipping...
# Processing Record 964 | yanam
# Processing Record 965 | emba
# Processing Record 966 | billings
# Processing Record 967 | luba
# Processing Record 968 | berea
# Processing Record 969 | dongsheng
# Processing Record 970 | stornoway
# City not found.  Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(weather_list)
weather_df['Temperature (F)'] = (weather_df['Temperature'] * (9/5)) + 32
weather_df['Max Temp (F)'] = (weather_df['Max Temp'] * (9/5)) + 32
weather_df.to_csv('City Weather.csv')

weather_df.head()
# Out:
#           City  Cloudiness Country  Humidity  Latitude  Longitude  Max Temp  \
# 0      Rikitea           5      PF        78    -23.12    -134.97    23.009
# 1     Camacupa           0      AO        22    -12.02      17.48    12.509
# 2   Bredasdorp           0      ZA        87    -34.53      20.04     9.000
# 3  Yellowknife          75      CA        87     62.45    -114.38    15.000
# 4    Saskylakh          77      RU        56     71.97     114.09    14.708
#
#    Temperature  Wind Speed  Temperature (F)  Max Temp (F)
# 0       23.009        8.51          73.4162       73.4162
# 1       12.509        0.79          54.5162       54.5162
# 2        7.940        1.50          46.2920       48.2000
# 3       13.820        3.10          56.8760       59.0000
# 4       14.708        1.93          58.4744       58.4744

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Temperature (F)', figsize=(15,10), s=10)
plt.xlim(-80, 100)
plt.ylim(-100, 150)
# Out:
# (-100, 150)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Humidity', figsize=(15,10))
plt.xlim(-80, 100)
plt.ylim(-20, 120)
# Out:
# (-20, 120)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Cloudiness', figsize=(15,10))
plt.xlim(-80, 100)
plt.ylim(-20, 120)
# Out:
# (-20, 120)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind='scatter', x='Latitude', y='Wind Speed', figsize=(15,10))
plt.xlim(-80, 100)
plt.ylim(-5, 40)
# Out:
# (-5, 40)
